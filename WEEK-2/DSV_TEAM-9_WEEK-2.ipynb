# %% [markdown]
# # Import libraries required for data loading and analysis

# %%
import kagglehub
import os
import pandas as pd

path = kagglehub.dataset_download("nikitatkachenko/19332-spotify-songs")


print(os.listdir(path))

df = pd.read_csv(
    os.path.join(path, "19332_Spotify_Songs.csv"),
    encoding="latin1"
)
# Out:
# ['19332_Spotify_Songs.csv']
# C:\Users\Tejus\AppData\Local\Temp\ipykernel_2420\2651407780.py:13: DtypeWarning: Columns (9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %% [markdown]
# # Import libraries for plotting

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Display the first five rows of the dataset

# %%
df.head()
# Out:
#                        id                                            artists  \
# 0  000xQL6tZNLJzIrtIgxqSl  https://api.spotify.com/v1/artists/5ZsFI1h6hId...
# 1  001UkMQHw4zXfFNdKpwXAF  https://api.spotify.com/v1/artists/0XKOBt59crn...
# 2  003FTlCpBTM4eSqYSWPv4H  https://api.spotify.com/v1/artists/3vAaWhdBR38...
# 3  003vvx7Niy0yvhvHt4a68B  https://api.spotify.com/v1/artists/0C0XlULifJt...
# 4  005lwxGU1tms6HGELIcUv9  https://api.spotify.com/v1/artists/6jJ0s89eD6G...
#
#                                    available_markets  disc_number  \
# 0  AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR...            1
# 1  AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR...            1
# 2  AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR...            1
# 3  AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR...            1
# 4                                         CA, JP, US            1
#
#   duration_ms.x explicit                                               href  \
# ...

# %% [markdown]
# # Check the number of rows and columns in the dataset

# %%
df.shape
# Out:
# (19335, 46)

# %% [markdown]
# # Display the names of all columns

# %%
df.columns
# Out:
# Index(['id', 'artists', 'available_markets', 'disc_number', 'duration_ms.x',
#        'explicit', 'href', 'is_local', 'name', 'popularity', 'preview_url',
#        'track_number', 'type.x', 'uri.x', 'album.album_type', 'album.artists',
#        'album.available_markets', 'album.href', 'album.id', 'album.images',
#        'album.name', 'album.release_date', 'album.release_date_precision',
#        'album.total_tracks', 'album.type', 'album.uri',
#        'album.external_urls.spotify', 'external_ids.isrc',
#        'external_urls.spotify', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type.y', 'uri.y', 'track_href', 'analysis_url',
#        'duration_ms.y', 'time_signature'],
#       dtype='object')

# %% [markdown]
# # Check the structure, data types, and non-null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19335 entries, 0 to 19334
# Data columns (total 46 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            19333 non-null  object
#  1   artists                       19335 non-null  object
#  2   available_markets             19335 non-null  object
#  3   disc_number                   19335 non-null  int64
#  4   duration_ms.x                 19335 non-null  object
#  5   explicit                      19335 non-null  object
#  6   href                          19335 non-null  object
#  7   is_local                      19335 non-null  object
#  8   name                          19333 non-null  object
#  9   popularity                    19334 non-null  object
#  10  preview_url                   11811 non-null  object
#  11  track_number                  19334 non-null  object
# ...

# %% [markdown]
# # Check the number of missing values in each column

# %%
df.isnull().sum()
# Out:
# id                                 2
# artists                            0
# available_markets                  0
# disc_number                        0
# duration_ms.x                      0
# explicit                           0
# href                               0
# is_local                           0
# name                               2
# popularity                         1
# preview_url                     7524
# track_number                       1
# type.x                             1
# uri.x                              2
# album.album_type                   2
# album.artists                      2
# album.available_markets            2
# album.href                         2
# album.id                           2
# album.images                       2
# album.name                         2
# album.release_date                 4
# album.release_date_precision       4
# album.total_tracks                 4
# album.type                         4
# ...

# %% [markdown]
# # Check the number of duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Generate descriptive statistics for numerical columns

# %%
df.describe()
# Out:
#         disc_number  danceability        energy           key      loudness  \
# count  19335.000000  19328.000000  19328.000000  19328.000000  19328.000000
# mean       1.020222      0.615997      0.584217      5.191743     -8.605355
# std        0.248414      0.179863      0.236897      3.568570      5.803552
# min        1.000000      0.000000      0.000020      0.000000    -54.376000
# 25%        1.000000      0.507000      0.443000      2.000000     -9.714000
# 50%        1.000000      0.638000      0.620000      5.000000     -6.816000
# 75%        1.000000      0.748000      0.765000      8.000000     -5.085000
# max       15.000000      0.985000      1.000000     11.000000      1.060000
#
#                mode   speechiness  acousticness  instrumentalness  \
# count  19328.000000  19328.000000  19328.000000      19328.000000
# mean       0.645281      0.107343      0.308663          0.102164
# std        0.478440      0.111756      0.321930          0.266955
# ...

# %% [markdown]
# # Check the number of unique values in each column

# %%
df.nunique()
# Out:
# id                              19332
# artists                          8788
# available_markets                 786
# disc_number                        10
# duration_ms.x                   14072
# explicit                            5
# href                            19334
# is_local                            5
# name                            16232
# popularity                        197
# preview_url                     11549
# track_number                      494
# type.x                              5
# uri.x                           19332
# album.album_type                    6
# album.artists                    5813
# album.available_markets           759
# album.href                      11035
# album.id                        11035
# album.images                    11035
# album.name                      10585
# album.release_date               3350
# album.release_date_precision        6
# album.total_tracks                115
# album.type                          4
# ...

# %% [markdown]
# ## First Impression
#
# The dataset contains information about Spotify songs and playlists, with both numerical and categorical columns. The dataset has a large number of records and provides different types of information about songs, such as genres, playlists, and audio-related features. The initial inspection helped identify the structure, data types, missing values, and duplicate records in the dataset. Overall, the dataset appears suitable for further analysis and visualization.
